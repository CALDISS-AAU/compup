# %% [markdown]
# # Pandas
#
# Pandas is a module that allows you to create dataframes in python: A spreadsheet-like data structure for data with rows and columns.
#
# The pandas modules contain a lot of instruments and methods for data handling and processing.
#
# A DataFrame is a type. An important subtype is a series: A one-dimensional datastructure with an index (like a type-specific list or a variable, as it is understood in statistics).

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series
# One dimensional data
# Data is labeled with a index
# Series consist of pairs (index, data)

# %%
a = pd.Series([4, 2, 7, 8, 4, 4])
print(a)
# Out:
# 0    4
# 1    2
# 2    7
# 3    8
# 4    4
# 5    4
# dtype: int64

# %%
a = pd.Series([4, 2, 7, 8, 4, 4])
print(a)
# Out:
# 0    4
# 1    2
# 2    7
# 3    8
# 4    4
# 5    4
# dtype: int64

# %%
print(a*2 + 4)
# Out:
# 0    12
# 1     8
# 2    18
# 3    20
# 4    12
# 5    12
# dtype: int64

# %%
print(a.unique())
# Out:
# [4 2 7 8]

# %%
print(a.isin([2, 4]))
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %% [markdown]
# # EXERCISE: Lists and Series
# 1. Create a list containing the numbers: 5, 13, 26, 42, 101
# 2. Try multiplying the list by 4 - What happens?
# 3. Create a panda series containing the same numbers (Note: you can create a panda series from a list)
# 4. Try multiplying the panda series by 4 - What happens?
# 5. Check if the number 20 is in your series using the .isin() method. (NOTE: isin() requires a list as input).

# %% [markdown]
# ## Pandas DataFrames
# - Two dimensional data (rows and columns)
# - Data is labelled with an index and a column name
# - With the pandas module, various files can be imported directly as dataframes (also from the web).
#
# We are working with a subset of the danish section of the 2018 European Social Survey: http://www.europeansocialsurvey.org/

# %%
ess_dk = pd.read_csv('https://raw.githubusercontent.com/CALDISS-AAU/workshop_R-intro/master/data/ESS2018DK_subset.csv')

# %%
ess_dk.head()
# Out:
#    idno  netustm  ppltrst                  vote  \
# 0   110    180.0      8.0                   Yes
# 1   705     60.0      5.0                   Yes
# 2  1327    240.0      5.0                   NaN
# 3  3760    300.0      7.0  Not eligible to vote
# 4  4658     90.0      8.0                   Yes
#
#                                             prtvtddk  \
# 0           Socialdemokratiet - The Social democrats
# 1  Det Konservative Folkeparti - Conservative Peo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        lvpntyr           tygrtr    gndr  \
# 0                                         1968  Never too young    Male
# 1                                         1976               67    Male
# 2  Still in parental home, never left 2 months              NaN    Male
# ...

# %%
ess_dk.tail()
# Out:
#         idno  netustm  ppltrst                  vote  \
# 1567  149977    600.0      8.0  Not eligible to vote
# 1568  150131    600.0     10.0                   Yes
# 1569  150359    120.0      8.0                   Yes
# 1570  150390    480.0      7.0                   Yes
# 1571  150446      NaN      4.0                    No
#
#                                                prtvtddk lvpntyr  \
# 1567                                                NaN    1996
# 1568  Det Konservative Folkeparti - Conservative Peo...    1992
# 1569  Venstre, Danmarks Liberale Parti - The Liberal...    1958
# 1570   Det Radikale Venstre - The Radical Liberal Party    2008
# 1571                                                NaN    1944
#
#                                tygrtr    gndr  yrbrn  \
# 1567                               50    Male   1975
# 1568                  Never too young  Female   1976
# 1569  Should never retire permanently    Male   1938
# ...

# %%
ess_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572 entries, 0 to 1571
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   idno      1572 non-null   int64
#  1   netustm   1395 non-null   float64
#  2   ppltrst   1568 non-null   float64
#  3   vote      1566 non-null   object
#  4   prtvtddk  1230 non-null   object
#  5   lvpntyr   1562 non-null   object
#  6   tygrtr    1383 non-null   object
#  7   gndr      1572 non-null   object
#  8   yrbrn     1572 non-null   int64
#  9   edlvddk   1569 non-null   object
#  10  eduyrs    1559 non-null   float64
#  11  wkhct     1448 non-null   float64
#  12  wkhtot    1502 non-null   float64
#  13  grspnum   820 non-null    float64
#  14  frlgrsp   274 non-null    float64
#  15  inwtm     1566 non-null   float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 196.6+ KB

# %%
list(ess_dk.columns)
# Out:
# ['idno',
#  'netustm',
#  'ppltrst',
#  'vote',
#  'prtvtddk',
#  'lvpntyr',
#  'tygrtr',
#  'gndr',
#  'yrbrn',
#  'edlvddk',
#  'eduyrs',
#  'wkhct',
#  'wkhtot',
#  'grspnum',
#  'frlgrsp',
#  'inwtm']

# %%
ess_dk.describe()
# Out:
#                 idno      netustm      ppltrst        yrbrn       eduyrs  \
# count    1572.000000  1395.000000  1568.000000  1572.000000  1559.000000
# mean   110821.670483   232.204301     7.063138  1968.245547    13.678640
# std     26076.703893   193.175426     1.813012    19.188190     5.781205
# min       110.000000     0.000000     0.000000  1929.000000     0.000000
# 25%     93622.750000    90.000000     6.000000  1953.000000    11.000000
# 50%    112966.000000   180.000000     7.000000  1967.000000    14.000000
# 75%    131429.750000   330.000000     8.000000  1984.000000    17.000000
# max    150446.000000  1020.000000    10.000000  2003.000000    40.000000
#
#              wkhct       wkhtot       grspnum       frlgrsp        inwtm
# count  1448.000000  1502.000000  8.200000e+02  2.740000e+02  1566.000000
# mean     33.229282    36.171771  9.598654e+04  6.304640e+04    62.676884
# std      10.568167    13.205436  2.935044e+05  1.616759e+05    24.774517
# ...

# %%
ess_dk[0:1]
# Out:
#    idno  netustm  ppltrst vote                                  prtvtddk  \
# 0   110    180.0      8.0  Yes  Socialdemokratiet - The Social democrats
#
#   lvpntyr           tygrtr  gndr  yrbrn  \
# 0    1968  Never too young  Male   1949
#
#                                              edlvddk  eduyrs  wkhct  wkhtot  \
# 0  Kort videregående uddannelse af op til 2-3 års...     9.0   28.0    28.0
#
#    grspnum  frlgrsp  inwtm
# 0      NaN      NaN  119.0

# %%
ess_dk['wkhct']
# Out:
# 0       28.0
# 1       37.0
# 2       37.0
# 3        2.0
# 4       30.0
#         ...
# 1567    37.0
# 1568    37.0
# 1569    50.0
# 1570    37.0
# 1571    40.0
# Name: wkhct, Length: 1572, dtype: float64

# %%
ess_dk.loc[2:4, 'wkhct']
# Out:
# 2    37.0
# 3     2.0
# 4    30.0
# Name: wkhct, dtype: float64

# %%
ess_dk.loc[2:4, ['wkhct', 'yrbrn']]
# Out:
#    wkhct  yrbrn
# 2   37.0   2000
# 3    2.0   2002
# 4   30.0   1956

# %%
(ess_dk['netustm'] / 60).head()
# Out:
# 0    3.0
# 1    1.0
# 2    4.0
# 3    5.0
# 4    1.5
# Name: netustm, dtype: float64

# %%
ess_dk.sort_values(by=['ppltrst'])
# Out:
#         idno  netustm  ppltrst                  vote  \
# 149    80205      NaN      0.0                   Yes
# 189    82701    600.0      0.0                   Yes
# 1108  128246     60.0      0.0                   Yes
# 220    84103    915.0      0.0                    No
# 613   105339      NaN      0.0                   Yes
# ...      ...      ...      ...                   ...
# 1366  139560    720.0     10.0                   Yes
# 457    96743    240.0      NaN                    No
# 572   103492     60.0      NaN                   Yes
# 817   114277    330.0      NaN  Not eligible to vote
# 1356  139291     60.0      NaN                    No
#
#                                                prtvtddk  \
# 149                                                 NaN
# 189   Enhedslisten - Unity List - The Red-Green Alli...
# 1108  Venstre, Danmarks Liberale Parti - The Liberal...
# 220                                                 NaN
# ...

# %%
ess_dk.sort_values(by=['ppltrst'], na_position='first')
# Out:
#         idno  netustm  ppltrst                  vote  \
# 457    96743    240.0      NaN                    No
# 572   103492     60.0      NaN                   Yes
# 817   114277    330.0      NaN  Not eligible to vote
# 1356  139291     60.0      NaN                    No
# 149    80205      NaN      0.0                   Yes
# ...      ...      ...      ...                   ...
# 1287  136301    180.0     10.0                   Yes
# 591   104254      NaN     10.0                    No
# 1286  136193    150.0     10.0                   Yes
# 1302  136837    300.0     10.0                   Yes
# 1366  139560    720.0     10.0                   Yes
#
#                                                prtvtddk  \
# 457                                                 NaN
# 572   Venstre, Danmarks Liberale Parti - The Liberal...
# 817                                                 NaN
# 1356                                                NaN
# ...

# %%
ess_dk.head()
# Out:
#    idno  netustm  ppltrst                  vote  \
# 0   110    180.0      8.0                   Yes
# 1   705     60.0      5.0                   Yes
# 2  1327    240.0      5.0                   NaN
# 3  3760    300.0      7.0  Not eligible to vote
# 4  4658     90.0      8.0                   Yes
#
#                                             prtvtddk  \
# 0           Socialdemokratiet - The Social democrats
# 1  Det Konservative Folkeparti - Conservative Peo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        lvpntyr           tygrtr    gndr  \
# 0                                         1968  Never too young    Male
# 1                                         1976               67    Male
# 2  Still in parental home, never left 2 months              NaN    Male
# ...

# %% [markdown]
# # Merging and joining data

# %%
ess_fi = pd.read_csv ('https://raw.githubusercontent.com/CALDISS-AAU/compup/master/datasets/essfi_sub.csv', index_col=0)

# %%
ess_fi.head()
# Out:
#   cntry  idno  netustm  lvpntyr  ppltrst  vote  prtvtdfi  gndr  yrbrn  \
# 0    FI    19    120.0   1968.0        7   1.0       1.0     1   1947
# 1    FI    57    240.0   2008.0        8   1.0       1.0     1   1989
# 2    FI    86     60.0   1957.0        7   1.0      11.0     1   1941
# 3    FI   120    240.0   1988.0        7   1.0      11.0     1   1972
# 4    FI   164    570.0   1979.0        9   1.0       1.0     2   1961
#
#    edlvdfi  eduyrs  wkhct  wkhtot  grspnum  frlgrsp  inwtm
# 0      8.0    10.0    NaN     NaN      NaN      NaN   81.0
# 1     11.0    18.0   30.0    30.0   1800.0      NaN   51.0
# 2      2.0     8.0   38.0    38.0      NaN      NaN   44.0
# 3     11.0    21.0   39.0    39.0   2500.0      NaN   42.0
# 4      5.0    11.0   37.0    38.0   2450.0      NaN    NaN

# %%
ess_dk.head()
# Out:
#    idno  netustm  ppltrst                  vote  \
# 0   110    180.0      8.0                   Yes
# 1   705     60.0      5.0                   Yes
# 2  1327    240.0      5.0                   NaN
# 3  3760    300.0      7.0  Not eligible to vote
# 4  4658     90.0      8.0                   Yes
#
#                                             prtvtddk  \
# 0           Socialdemokratiet - The Social democrats
# 1  Det Konservative Folkeparti - Conservative Peo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        lvpntyr           tygrtr    gndr  \
# 0                                         1968  Never too young    Male
# 1                                         1976               67    Male
# 2  Still in parental home, never left 2 months              NaN    Male
# ...

# %%
import numpy as np

ess_dk['cntry'] = np.nan

# %%
ess_dk['cntry'] = ess_dk.loc[:,'cntry'] = 'DK'

# %%
ess_dk.head()
# Out:
#    idno  netustm  ppltrst                  vote  \
# 0   110    180.0      8.0                   Yes
# 1   705     60.0      5.0                   Yes
# 2  1327    240.0      5.0                   NaN
# 3  3760    300.0      7.0  Not eligible to vote
# 4  4658     90.0      8.0                   Yes
#
#                                             prtvtddk  \
# 0           Socialdemokratiet - The Social democrats
# 1  Det Konservative Folkeparti - Conservative Peo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        lvpntyr           tygrtr    gndr  \
# 0                                         1968  Never too young    Male
# 1                                         1976               67    Male
# 2  Still in parental home, never left 2 months              NaN    Male
# ...

# %%
ess = pd.concat([ess_dk, ess_fi])

# %%
ess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3327 entries, 0 to 1754
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   idno      3327 non-null   int64
#  1   netustm   2863 non-null   float64
#  2   ppltrst   3323 non-null   float64
#  3   vote      3308 non-null   object
#  4   prtvtddk  1230 non-null   object
#  5   lvpntyr   3305 non-null   object
#  6   tygrtr    1383 non-null   object
#  7   gndr      3327 non-null   object
#  8   yrbrn     3327 non-null   int64
#  9   edlvddk   1569 non-null   object
#  10  eduyrs    3306 non-null   float64
#  11  wkhct     3072 non-null   float64
#  12  wkhtot    3144 non-null   float64
#  13  grspnum   1682 non-null   float64
#  14  frlgrsp   710 non-null    float64
#  15  inwtm     3227 non-null   float64
#  16  cntry     3327 non-null   object
#  17  prtvtdfi  1205 non-null   float64
#  18  edlvdfi   1752 non-null   float64
# ...

# %% [markdown]
# # Exercise:
#
# - We would like to have a column called 'age' where we have the respondents age. We currently only have the coulm called 'yrbrn'.
# - The new column 'age' should be a part of our ESS-data and since the data is from 2018, we would like their age from that year.

# %%
ess_dk['age'] = 2018 - ess_dk['yrbrn']

# %%
ess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3327 entries, 0 to 1754
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   idno      3327 non-null   int64
#  1   netustm   2863 non-null   float64
#  2   ppltrst   3323 non-null   float64
#  3   vote      3308 non-null   object
#  4   prtvtddk  1230 non-null   object
#  5   lvpntyr   3305 non-null   object
#  6   tygrtr    1383 non-null   object
#  7   gndr      3327 non-null   object
#  8   yrbrn     3327 non-null   int64
#  9   edlvddk   1569 non-null   object
#  10  eduyrs    3306 non-null   float64
#  11  wkhct     3072 non-null   float64
#  12  wkhtot    3144 non-null   float64
#  13  grspnum   1682 non-null   float64
#  14  frlgrsp   710 non-null    float64
#  15  inwtm     3227 non-null   float64
#  16  cntry     3327 non-null   object
#  17  prtvtdfi  1205 non-null   float64
#  18  edlvdfi   1752 non-null   float64
# ...

# %%
ess_dk.head()
# Out:
#    idno  netustm  ppltrst                  vote  \
# 0   110    180.0      8.0                   Yes
# 1   705     60.0      5.0                   Yes
# 2  1327    240.0      5.0                   NaN
# 3  3760    300.0      7.0  Not eligible to vote
# 4  4658     90.0      8.0                   Yes
#
#                                             prtvtddk  \
# 0           Socialdemokratiet - The Social democrats
# 1  Det Konservative Folkeparti - Conservative Peo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        lvpntyr           tygrtr    gndr  \
# 0                                         1968  Never too young    Male
# 1                                         1976               67    Male
# 2  Still in parental home, never left 2 months              NaN    Male
# ...

# %%
ess_dk = ess_dk.dropna()
ess_dk.head()
# Out:
#      idno  netustm  ppltrst vote  \
# 5    5816     90.0      7.0  Yes
# 6    7251    300.0      5.0  Yes
# 7    7887    360.0      8.0  Yes
# 11  12355    120.0      5.0  Yes
# 15  20724     60.0      5.0  Yes
#
#                                              prtvtddk lvpntyr  \
# 5   SF Socialistisk Folkeparti - Socialist People'...    1994
# 6            Dansk Folkeparti - Danish People's Party    1993
# 7            Socialdemokratiet - The Social democrats    1983
# 11           Socialdemokratiet - The Social democrats    1987
# 15  Venstre, Danmarks Liberale Parti - The Liberal...    1981
#
#              tygrtr    gndr  yrbrn  \
# 5                60    Male   1974
# 6                40  Female   1975
# 7                55    Male   1958
# 11               60    Male   1963
# 15  Never too young    Male   1958
#
#                                               edlvddk  eduyrs  wkhct  wkhtot  \
# 5   Mellemlang videregående uddannelse af 3-4 års ...    35.0   37.0    37.0
# ...

# %% [markdown]
# #### Dropna
# We can specify different arguments when we use dropna. fx. we can use thresh=2, to specify that if there is two NaN in a row, then drop the row. Have a look at the documentation to see other arguments.

# %% [markdown]
# # Recoding
#
# Different ways to recode

# %%
import numpy as np

ess_dk['wkhtot_category'] = np.nan
ess_dk.head()
# Out:
#      idno  netustm  ppltrst vote  \
# 5    5816     90.0      7.0  Yes
# 6    7251    300.0      5.0  Yes
# 7    7887    360.0      8.0  Yes
# 11  12355    120.0      5.0  Yes
# 15  20724     60.0      5.0  Yes
#
#                                              prtvtddk lvpntyr  \
# 5   SF Socialistisk Folkeparti - Socialist People'...    1994
# 6            Dansk Folkeparti - Danish People's Party    1993
# 7            Socialdemokratiet - The Social democrats    1983
# 11           Socialdemokratiet - The Social democrats    1987
# 15  Venstre, Danmarks Liberale Parti - The Liberal...    1981
#
#              tygrtr    gndr  yrbrn  \
# 5                60    Male   1974
# 6                40  Female   1975
# 7                55    Male   1958
# 11               60    Male   1963
# 15  Never too young    Male   1958
#
#                                               edlvddk  eduyrs  wkhct  wkhtot  \
# 5   Mellemlang videregående uddannelse af 3-4 års ...    35.0   37.0    37.0
# ...

# %%
mean_wkhtot = ess_dk['wkhtot'].mean()

# %%
ess_dk.loc[(ess_dk['wkhtot'] <= mean_wkhtot), 'wkhtot_category'] = "low"
ess_dk.loc[(ess_dk['wkhtot'] > mean_wkhtot), 'wkhtot_category'] = "high"
ess_dk.head()
# Out:
#      idno  netustm  ppltrst vote  \
# 5    5816     90.0      7.0  Yes
# 6    7251    300.0      5.0  Yes
# 7    7887    360.0      8.0  Yes
# 11  12355    120.0      5.0  Yes
# 15  20724     60.0      5.0  Yes
#
#                                              prtvtddk lvpntyr  \
# 5   SF Socialistisk Folkeparti - Socialist People'...    1994
# 6            Dansk Folkeparti - Danish People's Party    1993
# 7            Socialdemokratiet - The Social democrats    1983
# 11           Socialdemokratiet - The Social democrats    1987
# 15  Venstre, Danmarks Liberale Parti - The Liberal...    1981
#
#              tygrtr    gndr  yrbrn  \
# 5                60    Male   1974
# 6                40  Female   1975
# 7                55    Male   1958
# 11               60    Male   1963
# 15  Never too young    Male   1958
#
#                                               edlvddk  eduyrs  wkhct  wkhtot  \
# 5   Mellemlang videregående uddannelse af 3-4 års ...    35.0   37.0    37.0
# ...

# %% [markdown]
# # Exercise: Recoding
#
# - Create a new variable/column called ppltrst_category containing whether people have a high or low level of trust. You decide when people according to their score has a low or high amount of trust.
# - Look into the count of your distribution of respondents in ppltrst_category.

# %%
ess_dk.loc[(ess_dk['ppltrst'] <= 5), 'ppltrst_category'] = "low level of trust"
ess_dk.loc[(ess_dk['ppltrst'] > 5), 'ppltrst_category'] = "high level of trust"
ess_dk.head()
# Out:
#      idno  netustm  ppltrst vote  \
# 5    5816     90.0      7.0  Yes
# 6    7251    300.0      5.0  Yes
# 7    7887    360.0      8.0  Yes
# 11  12355    120.0      5.0  Yes
# 15  20724     60.0      5.0  Yes
#
#                                              prtvtddk lvpntyr  \
# 5   SF Socialistisk Folkeparti - Socialist People'...    1994
# 6            Dansk Folkeparti - Danish People's Party    1993
# 7            Socialdemokratiet - The Social democrats    1983
# 11           Socialdemokratiet - The Social democrats    1987
# 15  Venstre, Danmarks Liberale Parti - The Liberal...    1981
#
#              tygrtr    gndr  yrbrn  \
# 5                60    Male   1974
# 6                40  Female   1975
# 7                55    Male   1958
# 11               60    Male   1963
# 15  Never too young    Male   1958
#
#                                               edlvddk  eduyrs  wkhct  wkhtot  \
# 5   Mellemlang videregående uddannelse af 3-4 års ...    35.0   37.0    37.0
# ...

# %% [markdown]
# # Visualization
#
# Using the package called plotnine build on a package called ggplot from R.

# %%
ess_dk['gndr'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import plotnine as pn
from plotnine import *

# %%
ggplot(ess_dk) + aes(x='gndr') + geom_bar()
# Out:
# <ggplot: (179119624939)>

# %%
ggplot(ess_dk) + aes(x='gndr', fill='edlvddk') + geom_bar()
# Out:
# <ggplot: (179119663836)>

# %%
(ggplot(ess_dk) + aes(x='gndr', fill='edlvddk') + geom_bar()
    + xlab('Gender')
    + ylab('Count')
    + labs(fill='Education')
    + ggtitle('Education based on gender')
)
# Out:
# <ggplot: (179119709136)>

# %% [markdown]
# # Exercise
# - Make a plot where you visualize peoples trust (ppltrst) and what party they voted for during the last election (prtvtddk).
# - Add labels to your plot

# %%
(ggplot(ess_dk) + aes(x='ppltrst', fill='prtvtddk') + geom_bar()
    + xlab('Trust')
    + ylab('Count')
    + labs(fill='Party')
    + ggtitle('Party based on level of trust')
)
# Out:
# <ggplot: (179119807416)>
